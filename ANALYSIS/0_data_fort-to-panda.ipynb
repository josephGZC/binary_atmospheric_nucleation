# %%
# ===========================
# Investigated the homogeneous binary nucleation of atmospherically-relevant molecules
# =========================== 

# 🧱 Generate Dataframe: 
#     Conversion of fortran output files to pandas dataframe
# ---------------------------
# Table of Contents
# 1️⃣ Convert fort to panda 💤->🐼
# 2️⃣ Review generated parquets
# ----------------------------

# %%
# ===============================
# Convert fort to panda 💤->🐼
# ===============================
# 📆 Date created: October 12, 2024
# 📆 Date updated: October 14, 2024
# - generates parquet files instead of feather

import pandas as pd
import glob
import re
import os
import pyarrow as pa
import pyarrow.parquet as pq

# Initialize variables
data_rows = []
batch_number = 1
files_processed = 0
batch_size = 10  # Number of files to process in each batch
batch_parquet_files = []  # List to keep track of batch Parquet filenames

# Get the list of all fort.9* files and sort them numerically
file_list = sorted(glob.glob('fort.9*'), key=lambda x: int(re.match(r'fort\.(\d+)', x).group(1)))

print(f"Files found: {file_list}")

# Check if any files were found
if not file_list:
    print("No files found matching the pattern 'fort.9*'. Please check the file names and the directory.")
else:
    # Iterate over each file
    for filename in file_list:
        # Extract the number from the filename
        match = re.match(r'fort\.(\d+)', filename)
        if match:
            file_number = int(match.group(1))
        else:
            print(f"Filename {filename} does not match the expected pattern 'fort.<number>'. Skipping this file.")
            continue

        # Set verbose flag based on file number
        verbose = file_number >= 9070

        print(f"\nProcessing file: {filename}")

        with open(filename, 'r') as f:
            lines = f.readlines()

        frame_number = None
        num_lines = len(lines)
        line_index = 0

        # Parse the FRAME Number from the first line
        while line_index < num_lines:
            line = lines[line_index]
            frame_match = re.match(r' *FRAME\s+(\d+)\s+TIME \(ns\)\s+([\d\.]+)', line)
            if frame_match:
                frame_number = int(frame_match.group(1))
                time_ns = float(frame_match.group(2))
                line_index += 1
                break
            else:
                line_index += 1

        if frame_number is None:
            print(f"Could not find FRAME information in file {filename}. Skipping this file.")
            continue  # Skip to next file

        # Skip lines until we reach the '****NUCLEUS' section
        while line_index < num_lines:
            line = lines[line_index].strip()
            if line.startswith('****NUCLEUS'):
                break
            line_index += 1

        # Process each NUCLEUS entry
        nucleus_found = False  # Flag to check if any nucleus entries were found
        while line_index < num_lines:
            line = lines[line_index].strip()
            nucleus_match = re.match(r'\*\*\*\*NUCLEUS\s+(\d+)', line)
            if nucleus_match:
                nucleus_found = True
                nucleus_id = int(nucleus_match.group(1))
                line_index += 1  # Move to the comment line

                # Read the comment line and extract Size and number of atoms
                if line_index >= num_lines:
                    if verbose:
                        print(f"Unexpected end of file after NUCLEUS ID {nucleus_id} in file {filename}.")
                    break
                comment_line = lines[line_index].strip()
                size_line_parts = comment_line.split('|')
                if len(size_line_parts) >= 3:
                    size_part = size_line_parts[0].split()
                    try:
                        size = int(size_part[-1])
                        num_atoms = int(size_line_parts[2].strip())
                    except ValueError as e:
                        if verbose:
                            print(f"Error parsing size or number of atoms for NUCLEUS ID {nucleus_id} in file {filename}: {e}")
                        break
                else:
                    if verbose:
                        print(f"Error parsing comment line in file {filename} at line {line_index}")
                    break
                line_index += 1  # Move to atom data lines

                # Read atom data lines
                for atom_idx in range(num_atoms):
                    if line_index >= num_lines:
                        if verbose:
                            print(f"Unexpected end of file when reading atoms for NUCLEUS ID {nucleus_id} in file {filename}.")
                        break
                    atom_line = lines[line_index].strip()
                    atom_parts = atom_line.split()
                    if len(atom_parts) >= 5:
                        try:
                            molecule_name = atom_parts[0]
                            atom_name = atom_parts[1]
                            molecule_id = atom_parts[2]
                            x = float(atom_parts[3])
                            y = float(atom_parts[4])
                            z = float(atom_parts[5])
                        except ValueError as e:
                            if verbose:
                                print(f"Error parsing atom coordinates for NUCLEUS ID {nucleus_id} in file {filename} at line {line_index}: {e}")
                            break
                    else:
                        if verbose:
                            print(f"Error parsing atom line in file {filename} at line {line_index}: {atom_line}")
                            break

                    # Append data to the list
                    data_rows.append({
                        'frame_number': frame_number,
                        'nucleus_id': nucleus_id,
                        'size': size,
                        'molecule_name': molecule_name,
                        'molecule_id': molecule_id,
                        'atom_name': atom_name,
                        'x_coord': x,
                        'y_coord': y,
                        'z_coord': z,
                    })
                    line_index += 1

                # Skip any blank lines after the atom data
                while line_index < num_lines and lines[line_index].strip() == '':
                    line_index += 1
            else:
                line_index += 1  # Move to the next line if not a NUCLEUS entry

        if nucleus_found:
            print(f"Successfully read data from file {filename}.")
        else:
            print(f"No NUCLEUS entries found in file {filename}.")

        files_processed += 1

        # Check if we've reached the batch size
        if files_processed % batch_size == 0 or filename == file_list[-1]:
            # Create the DataFrame from the collected data
            df = pd.DataFrame(data_rows)

            # Define batch Parquet filename with the requested naming convention
            batch_filename = f'nuc_fort-to-panda_batch_{batch_number}.parquet'
            batch_parquet_files.append(batch_filename)

            # Write the batch to a Parquet file
            df.to_parquet(batch_filename, index=False)
            print(f"\nBatch {batch_number}: Data written to '{batch_filename}'.")

            # Reset data_rows and increment batch number
            data_rows = []
            batch_number += 1

    # Combine all batch Parquet files into a single Parquet file
    output_filename = 'nuc_fort-to-panda_combined.parquet'
    print(f"\nCombining batch files into '{output_filename}'...")

    # Read all batch Parquet files and append to a list
    tables = []
    for batch_file in batch_parquet_files:
        table = pq.read_table(batch_file)
        tables.append(table)
        print(f"Added '{batch_file}' to the combined Parquet file.")

    # Concatenate all tables
    combined_table = pa.concat_tables(tables)

    # Write the combined table to the output Parquet file
    pq.write_table(combined_table, output_filename)
    print(f"\nAll data has been written to '{output_filename}'.")
    print(f"Individual batch Parquet files have been kept.")
# Out:
# Files found: ['fort.9000', 'fort.9001', 'fort.9002', 'fort.9003', 'fort.9004', 'fort.9005', 'fort.9006', 'fort.9007', 'fort.9008', 'fort.9009', 'fort.9010', 'fort.9011', 'fort.9012', 'fort.9013', 'fort.9014', 'fort.9015', 'fort.9016', 'fort.9017', 'fort.9018', 'fort.9019', 'fort.9020', 'fort.9021', 'fort.9022', 'fort.9023', 'fort.9024', 'fort.9025', 'fort.9026', 'fort.9027', 'fort.9028', 'fort.9029', 'fort.9030', 'fort.9031', 'fort.9032', 'fort.9033', 'fort.9034', 'fort.9035', 'fort.9036', 'fort.9037', 'fort.9038', 'fort.9039', 'fort.9040', 'fort.9041', 'fort.9042', 'fort.9043', 'fort.9044', 'fort.9045', 'fort.9046', 'fort.9047', 'fort.9048', 'fort.9049', 'fort.9050', 'fort.9051', 'fort.9052', 'fort.9053', 'fort.9054', 'fort.9055', 'fort.9056', 'fort.9057', 'fort.9058', 'fort.9059', 'fort.9060', 'fort.9061', 'fort.9062', 'fort.9063', 'fort.9064', 'fort.9065', 'fort.9066', 'fort.9067', 'fort.9068', 'fort.9069', 'fort.9070', 'fort.9071', 'fort.9072', 'fort.9073', 'fort.9074', 'fort.9075', 'fort.9076', 'fort.9077', 'fort.9078', 'fort.9079', 'fort.9080', 'fort.9081', 'fort.9082', 'fort.9083', 'fort.9084', 'fort.9085', 'fort.9086', 'fort.9087', 'fort.9088', 'fort.9089', 'fort.9090', 'fort.9091', 'fort.9092', 'fort.9093', 'fort.9094', 'fort.9095', 'fort.9096', 'fort.9097', 'fort.9098', 'fort.9099', 'fort.9100', 'fort.9101', 'fort.9102', 'fort.9103', 'fort.9104', 'fort.9105', 'fort.9106', 'fort.9107', 'fort.9108', 'fort.9109', 'fort.9110', 'fort.9111', 'fort.9112', 'fort.9113', 'fort.9114', 'fort.9115', 'fort.9116', 'fort.9117', 'fort.9118', 'fort.9119', 'fort.9120', 'fort.9121', 'fort.9122', 'fort.9123', 'fort.9124', 'fort.9125', 'fort.9126', 'fort.9127', 'fort.9128', 'fort.9129', 'fort.9130', 'fort.9131', 'fort.9132', 'fort.9133', 'fort.9134', 'fort.9135', 'fort.9136', 'fort.9137', 'fort.9138', 'fort.9139', 'fort.9140', 'fort.9141', 'fort.9142', 'fort.9143', 'fort.9144', 'fort.9145', 'fort.9146', 'fort.9147', 'fort.9148', 'fort.9149', 'fort.9150', 'fort.9151', 'fort.9152', 'fort.9153', 'fort.9154', 'fort.9155', 'fort.9156', 'fort.9157', 'fort.9158', 'fort.9159', 'fort.9160', 'fort.9161', 'fort.9162', 'fort.9163', 'fort.9164', 'fort.9165', 'fort.9166', 'fort.9167', 'fort.9168', 'fort.9169', 'fort.9170', 'fort.9171', 'fort.9172', 'fort.9173', 'fort.9174', 'fort.9175', 'fort.9176', 'fort.9177', 'fort.9178', 'fort.9179', 'fort.9180', 'fort.9181', 'fort.9182', 'fort.9183', 'fort.9184', 'fort.9185', 'fort.9186', 'fort.9187', 'fort.9188', 'fort.9189', 'fort.9190', 'fort.9191', 'fort.9192', 'fort.9193', 'fort.9194', 'fort.9195', 'fort.9196', 'fort.9197', 'fort.9198', 'fort.9199', 'fort.9200']
#
# Processing file: fort.9000
# Successfully read data from file fort.9000.
#
# Processing file: fort.9001
# Successfully read data from file fort.9001.
#
# Processing file: fort.9002
# Successfully read data from file fort.9002.
#
# Processing file: fort.9003
# Successfully read data from file fort.9003.
#
# Processing file: fort.9004
# Successfully read data from file fort.9004.
#
# Processing file: fort.9005
# Successfully read data from file fort.9005.
#
# Processing file: fort.9006
# Successfully read data from file fort.9006.
#
# Processing file: fort.9007
# Successfully read data from file fort.9007.
#
# Processing file: fort.9008
# Successfully read data from file fort.9008.
#
# Processing file: fort.9009
# Successfully read data from file fort.9009.
#
# Batch 1: Data written to 'nuc_fort-to-panda_batch_1.parquet'.
#
# Processing file: fort.9010
# Successfully read data from file fort.9010.
#
# Processing file: fort.9011
# Successfully read data from file fort.9011.
#
# Processing file: fort.9012
# Successfully read data from file fort.9012.
#
# Processing file: fort.9013
# Successfully read data from file fort.9013.
#
# Processing file: fort.9014
# Successfully read data from file fort.9014.
#
# Processing file: fort.9015
# Successfully read data from file fort.9015.
#
# Processing file: fort.9016
# Successfully read data from file fort.9016.
#
# Processing file: fort.9017
# Successfully read data from file fort.9017.
#
# Processing file: fort.9018
# Successfully read data from file fort.9018.
#
# Processing file: fort.9019
# Successfully read data from file fort.9019.
#
# Batch 2: Data written to 'nuc_fort-to-panda_batch_2.parquet'.
#
# Processing file: fort.9020
# Successfully read data from file fort.9020.
#
# Processing file: fort.9021
# Successfully read data from file fort.9021.
#
# Processing file: fort.9022
# Successfully read data from file fort.9022.
#
# Processing file: fort.9023
# Successfully read data from file fort.9023.
#
# Processing file: fort.9024
# Successfully read data from file fort.9024.
#
# Processing file: fort.9025
# Successfully read data from file fort.9025.
#
# Processing file: fort.9026
# Successfully read data from file fort.9026.
#
# Processing file: fort.9027
# Successfully read data from file fort.9027.
#
# Processing file: fort.9028
# Successfully read data from file fort.9028.
#
# Processing file: fort.9029
# Successfully read data from file fort.9029.
#
# Batch 3: Data written to 'nuc_fort-to-panda_batch_3.parquet'.
#
# Processing file: fort.9030
# Successfully read data from file fort.9030.
#
# Processing file: fort.9031
# Successfully read data from file fort.9031.
#
# Processing file: fort.9032
# Successfully read data from file fort.9032.
#
# Processing file: fort.9033
# Successfully read data from file fort.9033.
#
# Processing file: fort.9034
# Successfully read data from file fort.9034.
#
# Processing file: fort.9035
# Successfully read data from file fort.9035.
#
# Processing file: fort.9036
# Successfully read data from file fort.9036.
#
# Processing file: fort.9037
# Successfully read data from file fort.9037.
#
# Processing file: fort.9038
# Successfully read data from file fort.9038.
#
# Processing file: fort.9039
# Successfully read data from file fort.9039.
#
# Batch 4: Data written to 'nuc_fort-to-panda_batch_4.parquet'.
#
# Processing file: fort.9040
# Successfully read data from file fort.9040.
#
# Processing file: fort.9041
# Successfully read data from file fort.9041.
#
# Processing file: fort.9042
# Successfully read data from file fort.9042.
#
# Processing file: fort.9043
# Successfully read data from file fort.9043.
#
# Processing file: fort.9044
# Successfully read data from file fort.9044.
#
# Processing file: fort.9045
# Successfully read data from file fort.9045.
#
# Processing file: fort.9046
# Successfully read data from file fort.9046.
#
# Processing file: fort.9047
# Successfully read data from file fort.9047.
#
# Processing file: fort.9048
# Successfully read data from file fort.9048.
#
# Processing file: fort.9049
# Successfully read data from file fort.9049.
#
# Batch 5: Data written to 'nuc_fort-to-panda_batch_5.parquet'.
#
# Processing file: fort.9050
# Successfully read data from file fort.9050.
#
# Processing file: fort.9051
# Successfully read data from file fort.9051.
#
# Processing file: fort.9052
# Successfully read data from file fort.9052.
#
# Processing file: fort.9053
# Successfully read data from file fort.9053.
#
# Processing file: fort.9054
# Successfully read data from file fort.9054.
#
# Processing file: fort.9055
# Successfully read data from file fort.9055.
#
# Processing file: fort.9056
# Successfully read data from file fort.9056.
#
# Processing file: fort.9057
# Successfully read data from file fort.9057.
#
# Processing file: fort.9058
# Successfully read data from file fort.9058.
#
# Processing file: fort.9059
# Successfully read data from file fort.9059.
#
# Batch 6: Data written to 'nuc_fort-to-panda_batch_6.parquet'.
#
# Processing file: fort.9060
# Successfully read data from file fort.9060.
#
# Processing file: fort.9061
# Successfully read data from file fort.9061.
#
# Processing file: fort.9062
# Successfully read data from file fort.9062.
#
# Processing file: fort.9063
# Successfully read data from file fort.9063.
#
# Processing file: fort.9064
# Successfully read data from file fort.9064.
#
# Processing file: fort.9065
# Successfully read data from file fort.9065.
#
# Processing file: fort.9066
# Successfully read data from file fort.9066.
#
# Processing file: fort.9067
# Successfully read data from file fort.9067.
#
# Processing file: fort.9068
# Successfully read data from file fort.9068.
#
# Processing file: fort.9069
# Successfully read data from file fort.9069.
#
# Batch 7: Data written to 'nuc_fort-to-panda_batch_7.parquet'.
#
# Processing file: fort.9070
# Successfully read data from file fort.9070.
#
# Processing file: fort.9071
# Successfully read data from file fort.9071.
#
# Processing file: fort.9072
# Successfully read data from file fort.9072.
#
# Processing file: fort.9073
# Successfully read data from file fort.9073.
#
# Processing file: fort.9074
# Successfully read data from file fort.9074.
#
# Processing file: fort.9075
# Successfully read data from file fort.9075.
#
# Processing file: fort.9076
# Successfully read data from file fort.9076.
#
# Processing file: fort.9077
# Successfully read data from file fort.9077.
#
# Processing file: fort.9078
# Successfully read data from file fort.9078.
#
# Processing file: fort.9079
# Successfully read data from file fort.9079.
#
# Batch 8: Data written to 'nuc_fort-to-panda_batch_8.parquet'.
#
# Processing file: fort.9080
# Successfully read data from file fort.9080.
#
# Processing file: fort.9081
# Successfully read data from file fort.9081.
#
# Processing file: fort.9082
# Successfully read data from file fort.9082.
#
# Processing file: fort.9083
# Successfully read data from file fort.9083.
#
# Processing file: fort.9084
# Successfully read data from file fort.9084.
#
# Processing file: fort.9085
# Successfully read data from file fort.9085.
#
# Processing file: fort.9086
# Successfully read data from file fort.9086.
#
# Processing file: fort.9087
# Successfully read data from file fort.9087.
#
# Processing file: fort.9088
# Successfully read data from file fort.9088.
#
# Processing file: fort.9089
# Successfully read data from file fort.9089.
#
# Batch 9: Data written to 'nuc_fort-to-panda_batch_9.parquet'.
#
# Processing file: fort.9090
# Successfully read data from file fort.9090.
#
# Processing file: fort.9091
# Successfully read data from file fort.9091.
#
# Processing file: fort.9092
# Successfully read data from file fort.9092.
#
# Processing file: fort.9093
# Successfully read data from file fort.9093.
#
# Processing file: fort.9094
# Successfully read data from file fort.9094.
#
# Processing file: fort.9095
# Successfully read data from file fort.9095.
#
# Processing file: fort.9096
# Successfully read data from file fort.9096.
#
# Processing file: fort.9097
# Successfully read data from file fort.9097.
#
# Processing file: fort.9098
# Successfully read data from file fort.9098.
#
# Processing file: fort.9099
# Successfully read data from file fort.9099.
#
# Batch 10: Data written to 'nuc_fort-to-panda_batch_10.parquet'.
#
# Processing file: fort.9100
# Successfully read data from file fort.9100.
#
# Processing file: fort.9101
# Successfully read data from file fort.9101.
#
# Processing file: fort.9102
# Successfully read data from file fort.9102.
#
# Processing file: fort.9103
# Successfully read data from file fort.9103.
#
# Processing file: fort.9104
# Successfully read data from file fort.9104.
#
# Processing file: fort.9105
# Successfully read data from file fort.9105.
#
# Processing file: fort.9106
# Successfully read data from file fort.9106.
#
# Processing file: fort.9107
# Successfully read data from file fort.9107.
#
# Processing file: fort.9108
# Successfully read data from file fort.9108.
#
# Processing file: fort.9109
# Successfully read data from file fort.9109.
#
# Batch 11: Data written to 'nuc_fort-to-panda_batch_11.parquet'.
#
# Processing file: fort.9110
# Successfully read data from file fort.9110.
#
# Processing file: fort.9111
# Successfully read data from file fort.9111.
#
# Processing file: fort.9112
# Successfully read data from file fort.9112.
#
# Processing file: fort.9113
# Successfully read data from file fort.9113.
#
# Processing file: fort.9114
# Successfully read data from file fort.9114.
#
# Processing file: fort.9115
# Successfully read data from file fort.9115.
#
# Processing file: fort.9116
# Successfully read data from file fort.9116.
#
# Processing file: fort.9117
# Successfully read data from file fort.9117.
#
# Processing file: fort.9118
# Successfully read data from file fort.9118.
#
# Processing file: fort.9119
# Successfully read data from file fort.9119.
#
# Batch 12: Data written to 'nuc_fort-to-panda_batch_12.parquet'.
#
# Processing file: fort.9120
# Successfully read data from file fort.9120.
#
# Processing file: fort.9121
# Successfully read data from file fort.9121.
#
# Processing file: fort.9122
# Successfully read data from file fort.9122.
#
# Processing file: fort.9123
# Successfully read data from file fort.9123.
#
# Processing file: fort.9124
# Successfully read data from file fort.9124.
#
# Processing file: fort.9125
# Successfully read data from file fort.9125.
#
# Processing file: fort.9126
# Successfully read data from file fort.9126.
#
# Processing file: fort.9127
# Successfully read data from file fort.9127.
#
# Processing file: fort.9128
# Successfully read data from file fort.9128.
#
# Processing file: fort.9129
# Successfully read data from file fort.9129.
#
# Batch 13: Data written to 'nuc_fort-to-panda_batch_13.parquet'.
#
# Processing file: fort.9130
# Successfully read data from file fort.9130.
#
# Processing file: fort.9131
# Successfully read data from file fort.9131.
#
# Processing file: fort.9132
# Successfully read data from file fort.9132.
#
# Processing file: fort.9133
# Successfully read data from file fort.9133.
#
# Processing file: fort.9134
# Successfully read data from file fort.9134.
#
# Processing file: fort.9135
# Successfully read data from file fort.9135.
#
# Processing file: fort.9136
# Successfully read data from file fort.9136.
#
# Processing file: fort.9137
# Successfully read data from file fort.9137.
#
# Processing file: fort.9138
# Successfully read data from file fort.9138.
#
# Processing file: fort.9139
# Successfully read data from file fort.9139.
#
# Batch 14: Data written to 'nuc_fort-to-panda_batch_14.parquet'.
#
# Processing file: fort.9140
# Successfully read data from file fort.9140.
#
# Processing file: fort.9141
# Successfully read data from file fort.9141.
#
# Processing file: fort.9142
# Successfully read data from file fort.9142.
#
# Processing file: fort.9143
# Successfully read data from file fort.9143.
#
# Processing file: fort.9144
# Successfully read data from file fort.9144.
#
# Processing file: fort.9145
# Successfully read data from file fort.9145.
#
# Processing file: fort.9146
# Successfully read data from file fort.9146.
#
# Processing file: fort.9147
# Successfully read data from file fort.9147.
#
# Processing file: fort.9148
# Successfully read data from file fort.9148.
#
# Processing file: fort.9149
# Successfully read data from file fort.9149.
#
# Batch 15: Data written to 'nuc_fort-to-panda_batch_15.parquet'.
#
# Processing file: fort.9150
# Successfully read data from file fort.9150.
#
# Processing file: fort.9151
# Successfully read data from file fort.9151.
#
# Processing file: fort.9152
# Successfully read data from file fort.9152.
#
# Processing file: fort.9153
# Successfully read data from file fort.9153.
#
# Processing file: fort.9154
# Successfully read data from file fort.9154.
#
# Processing file: fort.9155
# Successfully read data from file fort.9155.
#
# Processing file: fort.9156
# Successfully read data from file fort.9156.
#
# Processing file: fort.9157
# Successfully read data from file fort.9157.
#
# Processing file: fort.9158
# Successfully read data from file fort.9158.
#
# Processing file: fort.9159
# Successfully read data from file fort.9159.
#
# Batch 16: Data written to 'nuc_fort-to-panda_batch_16.parquet'.
#
# Processing file: fort.9160
# Successfully read data from file fort.9160.
#
# Processing file: fort.9161
# Successfully read data from file fort.9161.
#
# Processing file: fort.9162
# Successfully read data from file fort.9162.
#
# Processing file: fort.9163
# Successfully read data from file fort.9163.
#
# Processing file: fort.9164
# Successfully read data from file fort.9164.
#
# Processing file: fort.9165
# Successfully read data from file fort.9165.
#
# Processing file: fort.9166
# Successfully read data from file fort.9166.
#
# Processing file: fort.9167
# Successfully read data from file fort.9167.
#
# Processing file: fort.9168
# Successfully read data from file fort.9168.
#
# Processing file: fort.9169
# Successfully read data from file fort.9169.
#
# Batch 17: Data written to 'nuc_fort-to-panda_batch_17.parquet'.
#
# Processing file: fort.9170
# Successfully read data from file fort.9170.
#
# Processing file: fort.9171
# Successfully read data from file fort.9171.
#
# Processing file: fort.9172
# Successfully read data from file fort.9172.
#
# Processing file: fort.9173
# Successfully read data from file fort.9173.
#
# Processing file: fort.9174
# Successfully read data from file fort.9174.
#
# Processing file: fort.9175
# Successfully read data from file fort.9175.
#
# Processing file: fort.9176
# Successfully read data from file fort.9176.
#
# Processing file: fort.9177
# Successfully read data from file fort.9177.
#
# Processing file: fort.9178
# Successfully read data from file fort.9178.
#
# Processing file: fort.9179
# Successfully read data from file fort.9179.
#
# Batch 18: Data written to 'nuc_fort-to-panda_batch_18.parquet'.
#
# Processing file: fort.9180
# Successfully read data from file fort.9180.
#
# Processing file: fort.9181
# Successfully read data from file fort.9181.
#
# Processing file: fort.9182
# Successfully read data from file fort.9182.
#
# Processing file: fort.9183
# Successfully read data from file fort.9183.
#
# Processing file: fort.9184
# Successfully read data from file fort.9184.
#
# Processing file: fort.9185
# Successfully read data from file fort.9185.
#
# Processing file: fort.9186
# Successfully read data from file fort.9186.
#
# Processing file: fort.9187
# Successfully read data from file fort.9187.
#
# Processing file: fort.9188
# Successfully read data from file fort.9188.
#
# Processing file: fort.9189
# Successfully read data from file fort.9189.
#
# Batch 19: Data written to 'nuc_fort-to-panda_batch_19.parquet'.
#
# Processing file: fort.9190
# Successfully read data from file fort.9190.
#
# Processing file: fort.9191
# Successfully read data from file fort.9191.
#
# Processing file: fort.9192
# Successfully read data from file fort.9192.
#
# Processing file: fort.9193
# Successfully read data from file fort.9193.
#
# Processing file: fort.9194
# Successfully read data from file fort.9194.
#
# Processing file: fort.9195
# Successfully read data from file fort.9195.
#
# Processing file: fort.9196
# Successfully read data from file fort.9196.
#
# Processing file: fort.9197
# Successfully read data from file fort.9197.
#
# Processing file: fort.9198
# Successfully read data from file fort.9198.
#
# Processing file: fort.9199
# Successfully read data from file fort.9199.
#
# Batch 20: Data written to 'nuc_fort-to-panda_batch_20.parquet'.
#
# Processing file: fort.9200
# Successfully read data from file fort.9200.
#
# Batch 21: Data written to 'nuc_fort-to-panda_batch_21.parquet'.
#
# Combining batch files into 'nuc_fort-to-panda_combined.parquet'...
# Added 'nuc_fort-to-panda_batch_1.parquet' to the combined Parquet file.
# Added 'nuc_fort-to-panda_batch_2.parquet' to the combined Parquet file.
# Added 'nuc_fort-to-panda_batch_3.parquet' to the combined Parquet file.
# Added 'nuc_fort-to-panda_batch_4.parquet' to the combined Parquet file.
# Added 'nuc_fort-to-panda_batch_5.parquet' to the combined Parquet file.
# Added 'nuc_fort-to-panda_batch_6.parquet' to the combined Parquet file.
# Added 'nuc_fort-to-panda_batch_7.parquet' to the combined Parquet file.
# Added 'nuc_fort-to-panda_batch_8.parquet' to the combined Parquet file.
# Added 'nuc_fort-to-panda_batch_9.parquet' to the combined Parquet file.
# Added 'nuc_fort-to-panda_batch_10.parquet' to the combined Parquet file.
# Added 'nuc_fort-to-panda_batch_11.parquet' to the combined Parquet file.
# Added 'nuc_fort-to-panda_batch_12.parquet' to the combined Parquet file.
# Added 'nuc_fort-to-panda_batch_13.parquet' to the combined Parquet file.
# Added 'nuc_fort-to-panda_batch_14.parquet' to the combined Parquet file.
# Added 'nuc_fort-to-panda_batch_15.parquet' to the combined Parquet file.
# Added 'nuc_fort-to-panda_batch_16.parquet' to the combined Parquet file.
# Added 'nuc_fort-to-panda_batch_17.parquet' to the combined Parquet file.
# Added 'nuc_fort-to-panda_batch_18.parquet' to the combined Parquet file.
# Added 'nuc_fort-to-panda_batch_19.parquet' to the combined Parquet file.
# Added 'nuc_fort-to-panda_batch_20.parquet' to the combined Parquet file.
# Added 'nuc_fort-to-panda_batch_21.parquet' to the combined Parquet file.
#
# All data has been written to 'nuc_fort-to-panda_combined.parquet'.
# Individual batch Parquet files have been kept.

# %%
# ===============================
# 2️⃣ Review generated parquets
# ===============================
import pandas as pd

# Remove wrapping
pd.set_option('display.width', 1000)

# Upload df
df_combined = pd.read_parquet('nuc_fort-to-panda_combined.parquet')

# Display the first few rows
print(" ")
print(df_combined.head())

print(" ")
print("--> Info of df under inspection:")
print(" ")
print(df_combined.info())

print(" ") 
print("--> Duplicate rows identified:")
print(" ")
duplicate = df_combined[df_combined.duplicated()]
print(duplicate)

print(" ")
print("--> NaN identified:")
print(" ")
print(df_combined.isna().sum())
# Out:
#
#    frame_number  nucleus_id  size molecule_name molecule_id atom_name  x_coord  y_coord  z_coord
# 0             0           1     1          BUTA           1       CAA   33.264   29.442   34.124
# 1             0           1     1          BUTA           1       CAB   33.154   29.539   34.076
# 2             0           1     1          BUTA           1       CAC   33.190   29.596   33.938
# 3             0           1     1          BUTA           1       CAD   33.116   29.723   33.889
# 4             0           1     1          BUTA           1       OAE   33.149   29.818   33.991
#
# --> Info of df under inspection:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9044640 entries, 0 to 9044639
# Data columns (total 9 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   frame_number   int64
#  1   nucleus_id     int64
#  2   size           int64
#  3   molecule_name  object
#  4   molecule_id    object
#  5   atom_name      object
#  6   x_coord        float64
#  7   y_coord        float64
#  8   z_coord        float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 621.0+ MB
# None
#
# --> Duplicate rows identified:
#
# Empty DataFrame
# Columns: [frame_number, nucleus_id, size, molecule_name, molecule_id, atom_name, x_coord, y_coord, z_coord]
# Index: []
#
# --> NaN identified:
#
# frame_number     0
# nucleus_id       0
# size             0
# molecule_name    0
# molecule_id      0
# atom_name        0
# x_coord          0
# y_coord          0
# z_coord          0
# dtype: int64
